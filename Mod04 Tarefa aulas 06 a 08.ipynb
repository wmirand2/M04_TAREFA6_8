# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

rj = requests.get(url)

rj.status_code
# Out:
# 200

# %%
mun_rj = rj.json()
mun_rj
fr_rj= pd.DataFrame(mun_rj['items'])
fr_rj.head()
# Out:
#    id_pleito tipo_interessado  interessado  cod_ibge  uf  \
# 0      11032        Município   Petrópolis   3303906  RJ
# 1      10923        Município      Niterói   3303302  RJ
# 2      11415        Município      Niterói   3303302  RJ
# 3      40740        Município   Petrópolis   3303906  RJ
# 4      65517        Município  Nova Iguaçu   3303500  RJ
#
#                 num_pvl              status          num_processo  \
# 0                  None  Arquivado a pedido  17944.001341/2013-78
# 1                  None            Deferido  17944.001314/2014-86
# 2                  None            Deferido  17944.001438/2008-13
# 3  PVL02.008447/2019-25            Deferido  17944.104583/2019-16
# 4  PVL02.000206/2023-14            Deferido  17944.102874/2023-48
#
#          data_protocolo                                      tipo_operacao  \
# 0  2017-03-31T17:18:53Z  Operação contratual interna (com garantia da U...
# 1  2015-11-12T02:00:00Z                        Operação contratual interna
# 2  2008-09-15T03:00:00Z                        Operação contratual interna
# 3  2020-07-31T13:38:52Z                        Operação contratual interna
# 4  2023-07-25T17:16:18Z                        Operação contratual interna
#
#                                           finalidade  \
# 0  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 1  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 2                          PAC - Saneamento - 2008 B
# 3                                     Infraestrutura
# 4                                     Infraestrutura
#
#                        tipo_credor  \
# 0  Instituição Financeira Nacional
# 1  Instituição Financeira Nacional
# 2  Instituição Financeira Nacional
# 3  Instituição Financeira Nacional
# 4  Instituição Financeira Nacional
#
#                                            credor moeda        valor  \
# 0                         Caixa Econômica Federal  Real  37046866.67
# 1                         Caixa Econômica Federal  Real  10000000.00
# 2                         Caixa Econômica Federal  Real   9700000.00
# 3                         Caixa Econômica Federal  Real  20000000.00
# 4  Agência de Fomento do Estado do Rio de Janeiro  Real  50000000.00
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 0                      0  19/12/2017
# 1                 0                      0  18/11/2015
# 2                 0                      0  23/09/2008
# 3                 0                      0  06/08/2020
# 4                 0                      0  28/07/2023

# %%
# 2) Seu código aqui
fr_rj['status'].value_counts()
# Out:
# Deferido                                                 101
# Arquivado                                                 53
# Regularizado                                              26
# Arquivado por decurso de prazo                            24
# Deferido (PVL-IF)                                         22
# Encaminhado à PGFN com manifestação técnica favorável     14
# Arquivado a pedido                                         6
# Em análise                                                 3
# Em retificação pelo interessado                            3
# Em retificação pelo interessado (PVL-IF)                   1
# Em retificação pelo credor                                 1
# Arquivado pela STN                                         1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
fr_rj['data_status'] = fr_rj['data_status'].astype(str)

print(fr_rj['data_status'].dtype)

fr_rj['ano'] = fr_rj['data_status'].str[-4:]

fr_rj.head()
# Out:
# object
#    id_pleito tipo_interessado  interessado  cod_ibge  uf  \
# 0      11032        Município   Petrópolis   3303906  RJ
# 1      10923        Município      Niterói   3303302  RJ
# 2      11415        Município      Niterói   3303302  RJ
# 3      40740        Município   Petrópolis   3303906  RJ
# 4      65517        Município  Nova Iguaçu   3303500  RJ
#
#                 num_pvl              status          num_processo  \
# 0                  None  Arquivado a pedido  17944.001341/2013-78
# 1                  None            Deferido  17944.001314/2014-86
# 2                  None            Deferido  17944.001438/2008-13
# 3  PVL02.008447/2019-25            Deferido  17944.104583/2019-16
# 4  PVL02.000206/2023-14            Deferido  17944.102874/2023-48
#
#          data_protocolo                                      tipo_operacao  \
# 0  2017-03-31T17:18:53Z  Operação contratual interna (com garantia da U...
# 1  2015-11-12T02:00:00Z                        Operação contratual interna
# 2  2008-09-15T03:00:00Z                        Operação contratual interna
# 3  2020-07-31T13:38:52Z                        Operação contratual interna
# 4  2023-07-25T17:16:18Z                        Operação contratual interna
#
#                                           finalidade  \
# 0  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 1  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 2                          PAC - Saneamento - 2008 B
# 3                                     Infraestrutura
# 4                                     Infraestrutura
#
#                        tipo_credor  \
# 0  Instituição Financeira Nacional
# 1  Instituição Financeira Nacional
# 2  Instituição Financeira Nacional
# 3  Instituição Financeira Nacional
# 4  Instituição Financeira Nacional
#
#                                            credor moeda        valor  \
# 0                         Caixa Econômica Federal  Real  37046866.67
# 1                         Caixa Econômica Federal  Real  10000000.00
# 2                         Caixa Econômica Federal  Real   9700000.00
# 3                         Caixa Econômica Federal  Real  20000000.00
# 4  Agência de Fomento do Estado do Rio de Janeiro  Real  50000000.00
#
#    pvl_assoc_divida  pvl_contradado_credor data_status   ano
# 0                 0                      0  19/12/2017  2017
# 1                 0                      0  18/11/2015  2015
# 2                 0                      0  23/09/2008  2008
# 3                 0                      0  06/08/2020  2020
# 4                 0                      0  28/07/2023  2023

# %%
# 4)

fr_rj['ano'].value_counts()
# Out:
# 2008    37
# 2007    29
# 2023    24
# 2014    20
# 2010    19
# 2019    17
# 2013    15
# 2020    15
# 2012    13
# 2022    11
# 2011    10
# 2009     9
# 2015     8
# 2017     5
# 2021     5
# 2002     4
# 2016     4
# 2018     4
# 2006     4
# 2003     1
# 2004     1
# Name: ano, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Munic%C3%ADpio'
url1 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado'  

uf_ba = requests.get(url)
uf_mg = requests.get(url1)

uf_ba.status_code
uf_mg.status_code

mun_ba = uf_ba.json()
est_mg = uf_mg.json()

mun_ba 
est_mg

munic_ba = pd.DataFrame(mun_ba['items'])
munic_ba.head(2)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      22897        Município    Cotegipe   2909406  BA  PVL02.000001/2016-18
# 1      42369        Município    Macaúbas   2919801  BA  PVL02.000962/2020-09
#
#                            status          num_processo        data_protocolo  \
# 0  Arquivado por decurso de prazo  17944.000820/2016-10  2016-08-02T03:00:00Z
# 1               Deferido (PVL-IF)                  None                  None
#
#                  tipo_operacao  \
# 0  Operação contratual interna
# 1  Operação contratual interna
#
#                                        finalidade  \
# 0                                  Infraestrutura
# 1  Aquisição de máquinas, equipamentos e veículos
#
#                        tipo_credor                                     credor  \
# 0  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 1  Instituição Financeira Nacional                        Banco do Brasil S/A
#
#   moeda      valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  Real  1720000.0                 0                      0  08/11/2016
# 1  Real  1475383.0                 0                      1  23/07/2020

# %%
estado_mg = pd.DataFrame(est_mg['items'])
estado_mg.head(2)
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl    status  \
# 0      13549           Estado  Minas Gerais        31  MG    None  Deferido
# 1      10011           Estado  Minas Gerais        31  MG    None  Deferido
#
#            num_processo        data_protocolo                tipo_operacao  \
# 0  19405.000023/2006-93  2006-05-19T03:00:00Z  Operação contratual interna
# 1  17944.001099/2010-90  2010-08-23T03:00:00Z  Operação contratual interna
#
#        finalidade                      tipo_credor  \
# 0  Infraestrutura  Instituição Financeira Nacional
# 1            PMAE  Instituição Financeira Nacional
#
#                                               credor moeda         valor  \
# 0                                Banco do Brasil S/A  Iene  7.250000e+09
# 1  Banco Nacional de Desenvolvimento Econômico e ...  Real  4.674243e+06
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 1                      0  29/05/2006
# 1                 1                      0  25/08/2010

# %%
# 2) Seu código aqui
estado_mg['registradas'] = estado_mg['status'] == 'Arquivado por decurso de prazo'

estado_mg.registradas.value_counts()
# Out:
# False    39
# True      1
# Name: registradas, dtype: int64

# %%
# 3) Seu código aqui
munic_ba['deferidas'] = munic_ba['status'] == 'Deferido' 

munic_ba.loc[munic_ba['deferidas']]

municipios_deferidos = munic_ba.loc[munic_ba['deferidas']].copy()

municipios_deferidos.interessado.value_counts()
# Out:
# Luís Eduardo Magalhães    16
# Vitória da Conquista      12
# Barreiras                 10
# Camaçari                  10
# Lauro de Freitas          10
#                           ..
# Malhada                    1
# São Francisco do Conde     1
# Aracatu                    1
# Ibititá                    1
# Planaltino                 1
# Name: interessado, Length: 182, dtype: int64

# %%
# 4) Seu código aqui
url2 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'
ba1 = requests.get(url2)
ba1.status_code

est_ba1 = ba1.json()
est_ba1
frame_ba1 = pd.DataFrame(est_ba1['items'])


frame_ba1.to_csv('Solicitações da Bahia por Estado.csv')

frame_ba1.head(2)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      44369           Estado       Bahia        29  BA  PVL02.000482/2021-11
# 1      18535           Estado       Bahia        29  BA                  None
#
#      status          num_processo        data_protocolo  \
# 0  Deferido  17944.101324/2021-40  2021-05-03T19:36:30Z
# 1  Deferido  19407.000045/2002-18  2002-06-19T03:00:00Z
#
#                  tipo_operacao  \
# 0        Concessão de garantia
# 1  Operação contratual interna
#
#                                           finalidade  \
# 0  Concessão de garantia a empresa estatal não de...
# 1                                  Saneamento básico
#
#                        tipo_credor                   credor moeda  \
# 0              Outras Organizações          Pessoa Jurídica  Real
# 1  Instituição Financeira Nacional  Caixa Econômica Federal  Real
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  499000000.0                 0                      0  17/05/2021
# 1    2975000.0                 1                      0  05/07/2002
